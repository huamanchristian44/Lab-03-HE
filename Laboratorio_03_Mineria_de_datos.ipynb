# %% [markdown]
# <a href="https://colab.research.google.com/github/huamanchristian44/Lab-03-HE/blob/develop/Laboratorio_03_Mineria_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importando librerías
import pandas as pd

# %%
# Almacenando la información en una variable
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/car/car.data"

# %%
# Lectura de la data
data = pd.read_csv(url)
data
# Out:
#       vhigh vhigh.1      2   2.1  small   low  unacc
# 0     vhigh   vhigh      2     2  small   med  unacc
# 1     vhigh   vhigh      2     2  small  high  unacc
# 2     vhigh   vhigh      2     2    med   low  unacc
# 3     vhigh   vhigh      2     2    med   med  unacc
# 4     vhigh   vhigh      2     2    med  high  unacc
# ...     ...     ...    ...   ...    ...   ...    ...
# 1722    low     low  5more  more    med   med   good
# 1723    low     low  5more  more    med  high  vgood
# 1724    low     low  5more  more    big   low  unacc
# 1725    low     low  5more  more    big   med   good
# 1726    low     low  5more  more    big  high  vgood
#
# [1727 rows x 7 columns]

# %%
# Corrección de los nombres de atributos
data = pd.read_csv(url, names=["buying","maint","doors","persons","lug_boot","safety","acceptability"])
data
# Out:
#      buying  maint  doors persons lug_boot safety acceptability
# 0     vhigh  vhigh      2       2    small    low         unacc
# 1     vhigh  vhigh      2       2    small    med         unacc
# 2     vhigh  vhigh      2       2    small   high         unacc
# 3     vhigh  vhigh      2       2      med    low         unacc
# 4     vhigh  vhigh      2       2      med    med         unacc
# ...     ...    ...    ...     ...      ...    ...           ...
# 1723    low    low  5more    more      med    med          good
# 1724    low    low  5more    more      med   high         vgood
# 1725    low    low  5more    more      big    low         unacc
# 1726    low    low  5more    more      big    med          good
# 1727    low    low  5more    more      big   high         vgood
#
# [1728 rows x 7 columns]

# %%
# Extraer columnas
list(data)
# Out:
# ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'acceptability']

# %%
list(data.columns)
# Out:
# ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'acceptability']

# %%
data.columns.tolist()
# Out:
# ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'acceptability']

# %%
list(data.columns.values)
# Out:
# ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'acceptability']

# %%
# Medición del rendimiento
from timeit import timeit
t1 = timeit(lambda: list(data))
t2 = timeit(lambda: list(data.columns))
t3 = timeit(lambda: list(data.columns.tolist()))
t4 = timeit(lambda: list(data.columns.values))
print(t1,t2,t3,t4)
# Out:
# 2.2414998720000767 2.1514788760000556 0.818781212000431 1.8327123090002715

# %%
# Naturaleza de los atributos
data['buying'].dtype
# Out:
# dtype('O')

# %%
data['persons'].dtype
# Out:
# dtype('O')

# %%
data.dtypes
# Out:
# buying           object
# maint            object
# doors            object
# persons          object
# lug_boot         object
# safety           object
# acceptability    object
# dtype: object

# %%
# Cantidad de categorías en el atributo "doors"
data["doors"].unique()
# Out:
# array(['2', '3', '4', '5more'], dtype=object)

# %%
# Cambiando tipo de datos
data['doors'] = data['doors'].astype('category')
data['persons'] = data['persons'].astype('category')
data['buying'] = data['buying'].astype('category')
data['maint'] = data['maint'].astype('category')
data['lug_boot'] = data['lug_boot'].astype('category')
data['safety'] = data['safety'].astype('category')
data['acceptability'] = data['acceptability'].astype('category')

# %%
data.dtypes
# Out:
# buying           category
# maint            category
# doors            category
# persons          category
# lug_boot         category
# safety           category
# acceptability    category
# dtype: object

# %%
# Cambiando nombre a categorías
import numpy as np
data["lug_boot"] = np.where(data["lug_boot"]=="small","pequeño",data["lug_boot"])
data["lug_boot"] = np.where(data["lug_boot"]=="med","mediano",data["lug_boot"])
data["lug_boot"] = np.where(data["lug_boot"]=="big","grande",data["lug_boot"])
data["lug_boot"].unique()
# Out:
# array(['pequeño', 'mediano', 'grande'], dtype=object)

# %%
# Contabilizando las frecuencias
data['doors'].value_counts(dropna=False)
# Out:
# doors
# 2        432
# 3        432
# 4        432
# 5more    432
# Name: count, dtype: int64

# %%
data['persons'].value_counts(dropna=False)
# Out:
# persons
# 2       576
# 4       576
# more    576
# Name: count, dtype: int64

# %%
data['buying'].value_counts(dropna=False)
# Out:
# buying
# high     432
# low      432
# med      432
# vhigh    432
# Name: count, dtype: int64

# %%
data['maint'].value_counts(dropna=False)
# Out:
# maint
# high     432
# low      432
# med      432
# vhigh    432
# Name: count, dtype: int64

# %%
data['lug_boot'].value_counts(dropna=False)
# Out:
# lug_boot
# pequeño    576
# mediano    576
# grande     576
# Name: count, dtype: int64

# %%
data['safety'].value_counts(dropna=False)
# Out:
# safety
# high    576
# low     576
# med     576
# Name: count, dtype: int64

# %%
data['acceptability'].value_counts(dropna=False)
# Out:
# acceptability
# unacc    1210
# acc       384
# good       69
# vgood      65
# Name: count, dtype: int64

# %%
# Combinando categorías
data["doors"] = np.where(data["doors"]=="2","3 a menos",data["doors"])
data["doors"] = np.where(data["doors"]=="3","3 a menos",data["doors"])

data["doors"] = np.where(data["doors"]=="4","4 a más",data["doors"])
data["doors"] = np.where(data["doors"]=="5more","4 a más",data["doors"])

data["doors"].unique()
# Out:
# array(['3 a menos', '4 a más'], dtype=object)

# %%
# Renombrando encabezados
data.rename({'lug_boot' : 'trunk'}, axis=1, inplace=True)
data
# Out:
#      buying  maint      doors persons    trunk safety acceptability
# 0     vhigh  vhigh  3 a menos       2  pequeño    low         unacc
# 1     vhigh  vhigh  3 a menos       2  pequeño    med         unacc
# 2     vhigh  vhigh  3 a menos       2  pequeño   high         unacc
# 3     vhigh  vhigh  3 a menos       2  mediano    low         unacc
# 4     vhigh  vhigh  3 a menos       2  mediano    med         unacc
# ...     ...    ...        ...     ...      ...    ...           ...
# 1723    low    low    4 a más    more  mediano    med          good
# 1724    low    low    4 a más    more  mediano   high         vgood
# 1725    low    low    4 a más    more   grande    low         unacc
# 1726    low    low    4 a más    more   grande    med          good
# 1727    low    low    4 a más    more   grande   high         vgood
#
# [1728 rows x 7 columns]

# %%
# Número de registros y atributos
data.shape
# Out:
# (1728, 7)

# %%
# Cinco primeros registros
data.head()
# Out:
#   buying  maint      doors persons    trunk safety acceptability
# 0  vhigh  vhigh  3 a menos       2  pequeño    low         unacc
# 1  vhigh  vhigh  3 a menos       2  pequeño    med         unacc
# 2  vhigh  vhigh  3 a menos       2  pequeño   high         unacc
# 3  vhigh  vhigh  3 a menos       2  mediano    low         unacc
# 4  vhigh  vhigh  3 a menos       2  mediano    med         unacc

# %%
# Cinco últimos registros
data.tail()
# Out:
#      buying maint    doors persons    trunk safety acceptability
# 1723    low   low  4 a más    more  mediano    med          good
# 1724    low   low  4 a más    more  mediano   high         vgood
# 1725    low   low  4 a más    more   grande    low         unacc
# 1726    low   low  4 a más    more   grande    med          good
# 1727    low   low  4 a más    more   grande   high         vgood

# %%
# Segmentación de filas y columnas
data.iloc[0:3,1:4]
# Out:
#    maint      doors persons
# 0  vhigh  3 a menos       2
# 1  vhigh  3 a menos       2
# 2  vhigh  3 a menos       2

# %%
# Extrayendo dos registros particulares
data.loc[[0,10],:]
# Out:
#    buying  maint      doors persons    trunk safety acceptability
# 0   vhigh  vhigh  3 a menos       2  pequeño    low         unacc
# 10  vhigh  vhigh  3 a menos       4  pequeño    med         unacc

# %%
# Extrayendo los datos de una categoría en particular
data[data.buying == "vhigh"]
# Out:
#     buying  maint      doors persons    trunk safety acceptability
# 0    vhigh  vhigh  3 a menos       2  pequeño    low         unacc
# 1    vhigh  vhigh  3 a menos       2  pequeño    med         unacc
# 2    vhigh  vhigh  3 a menos       2  pequeño   high         unacc
# 3    vhigh  vhigh  3 a menos       2  mediano    low         unacc
# 4    vhigh  vhigh  3 a menos       2  mediano    med         unacc
# ..     ...    ...        ...     ...      ...    ...           ...
# 427  vhigh    low    4 a más    more  mediano    med           acc
# 428  vhigh    low    4 a más    more  mediano   high           acc
# 429  vhigh    low    4 a más    more   grande    low         unacc
# 430  vhigh    low    4 a más    more   grande    med           acc
# 431  vhigh    low    4 a más    more   grande   high           acc
#
# [432 rows x 7 columns]

# %%
# Empleando operadores lógicos y combinando condiciones
data[(data.safety == "med")|(data.safety == "high")]
# Out:
#      buying  maint      doors persons    trunk safety acceptability
# 1     vhigh  vhigh  3 a menos       2  pequeño    med         unacc
# 2     vhigh  vhigh  3 a menos       2  pequeño   high         unacc
# 4     vhigh  vhigh  3 a menos       2  mediano    med         unacc
# 5     vhigh  vhigh  3 a menos       2  mediano   high         unacc
# 7     vhigh  vhigh  3 a menos       2   grande    med         unacc
# ...     ...    ...        ...     ...      ...    ...           ...
# 1721    low    low    4 a más    more  pequeño   high          good
# 1723    low    low    4 a más    more  mediano    med          good
# 1724    low    low    4 a más    more  mediano   high         vgood
# 1726    low    low    4 a más    more   grande    med          good
# 1727    low    low    4 a más    more   grande   high         vgood
#
# [1152 rows x 7 columns]

# %%
# Exportando nuestro documento a un csv
ruta = 'D:\\data.csv'
data.to_csv(ruta)
